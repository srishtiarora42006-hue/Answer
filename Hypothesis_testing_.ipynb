# %% [markdown]
# <a href="https://colab.research.google.com/github/srishtiarora42006-hue/Answer/blob/main/Hypothesis_testing_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.   What is a null hypothesis (H₀) and why is it important in hypothesis testing?
#    -> Null hypothesis means statement of no change i.e H₀ , it shows that there is no effect of change , In hypothesis testing null hypothesis and alternative hypothesis play an important role as they help in decision making based on the p-value so accquired, if p-value is greater than or equal to alpha then we fail to reject H₀ and if p-value if less than alpha then we reject H₀ , here alpha acts as a cut off line for rejecting H₀.
#
# 2. What does the significance level (α) represent in hypothesis testing?
#
#    -> Significance level or alpha α represents a cut off value for the p-value to reject or fail to reject null hypothesis it is the value which gives affect choose a decison.
#
# 3. Differentiate between Type I and Type II errors.
#
#    -> Type- I error (false positive)
#
#        it refers to rejecting H₀ when it is actually true ,
#        for example- concluding the new campaign has increasesd sales when in actual it has not.
#
#      Type- II error (false negative)
#
#      it refers to taking the null hypothesis when in actual it has an effect or failing to reject H₀ when it in actual it shows no effect.
#      for example- concluding to close an add which increased sales assuming it had no effect
#
# 4. Explain the difference between a one-tailed and two-tailed test. Give an example of each.
#
#      -> one tailed tests refers to tests for a particular direction e.g incraese and decrease
#        for e.g- increase of sales in store A
#
#        Two tailed tests refers to test of any significant diffrences in both the directions i.e increase and decrease
#        for example- critical areas of sales in a particular region
#
# 5. A company claims that the average time to resolve a customer complaint is 10 minutes.A random sample of 9 complaints gives an average time of 12 minutes and a standard deviation of 3 minutes.At α = 0.05, test the claim.
#
#      -> A.T.Q  population mean= 10
#                sample size- 9
#                sample mean- 12
#                sample standard deviation- 3
#                α = 0.05
#       As the sample size is < 30 then we will continue with the t-test
#         H₀ = μ= 10
#         H₁= μ ≠ 10
#         so answer = 12-10/ 3/3 = 2 ,
#
# 6. When should you use a Z-test instead of a t-test?
#
#      -> when the sample size is greater than 30 and the population variance is known then we should use a z-test instaed of t-test.
#
# 7. The productivity of 6 employees was measured before and after a training program.
#
#
#
#
# .

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# At α = 0.05, test if the training improved productivity.
#
#  -> here H₀ (Null): Training has no effect
#
# H₁ (Alternative): Training improves productivity
#
#  now we calculate diffrences before and after training
#  55-50=5, 65-60=5,59-58=1, 58-55=3,63-62=1,59-56=3
#  mean of diffrences= 18/6=3
#
#  now we calculate standard deviations
#  5-3= 2, 5-3=2, 1-3= -2 , 3-3=0, 1-3= -2, 3-3=0
#  squaring = 4,4,4,0,4,0 sum= 16
#  sample s.d= 16/6-1 = 16/5 = 3.2
#  taking square root of 3.2= 1.79
#
# as we see as all the values are in one direction i.e all of them are increasing so we will do a paired t-test
# where = 3/ 0.73= 4.11
# now if α = 0.05 then value will be 2.015
#
# 4.11>2.015 hence we reject H₀ ,
# it is thus concluded that training did increase productivity.
#
# 8.  A company wants to test if product preference is independent of gender.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# At α = 0.05, test independence
#
#      -> H₀: Variables are independent of gender
#         H₁: Variables are dependent on gender
#          find expected value using formula
#          for (MALE , PRODUCT A) = 50*40/100 = 20
#          for (MALE, PRODUCT B0 = 50*60 / 100 = 30
#          for ( FEMALE, PRODUCT A) = 50*40 / 100 = 20
#          for (FEMALE, PRODUCT B) = 50*60/ 100 = 30
#           NOW (Male, A):(30−20)^2/20=100/20=5
#               (Male, B):(20−30)2/30=100/30≈3.33
#               (Female, A):(10−20)2/20=100/20=5
#               (Female, B):(40−30)2/30=100/30≈3.33
#
#               ADDING ALL= 16.66
#               FROM table if α = 0.05 then critical value = 3.841
#               so 16.66> 3.841
#               So we reject H₀
#
#               the calculated chi-square value is greater than the critical value, we reject the null hypothesis and conclude that the variables are dependent (not independent).
