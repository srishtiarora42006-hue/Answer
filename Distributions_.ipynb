# %% [markdown]
# <a href="https://colab.research.google.com/github/srishtiarora42006-hue/Answer/blob/main/Distributions_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1. Stimulate 30 rolls with = RANDBETWEEN(1,6) . What is the probability of getting a 3 exactly 5 times?

  -> The probability of getting a 3 exactly 5 times is 0.19211

# %% [markdown]
# ![Screenshot 2026-04-21 222008.png](data:image/png;base64,...)

# %% [markdown]
# 2. Generate 100 values in excel using continuous uniform distribution function RAND() and plot a histogram.Describe the shape of the the distribution .
#
#   ![Screenshot 2026-04-21 223102.png](data:image/png;base64,...)

# %% [markdown]
# 3. A dataset has a mean of 50 and a standard devaition of 5. What percenatge of values lie between 45 and 55 if the data follows a normal distribution.
#
#    -> Mean = 50
#       Standard devaiation = 5
#      If the data follows a normal distribution then the data covered in this interval would be 68%.
#
# 4. What is the concept of standardization (z-score) and why is it important in data analysis? Explain the formula and how standardization transforms a dataset?
#
#      -> The concept of standardization tells how many standard deviations away is a value away from mean, or its distance from the mean, it is an important aspect in data analysis as it helps to compare data from various datasets in a normal distribution the formula of standardization is
#      x - μ /σ , it transforms the data into a common sacale so that it becomes easier to comapre.
#
#
# 5. What is kurtosis and their types?
#
#       -> Kurtosis refers to taildness of a distribution , that is how peak or low the values are at extreme , it helps to detect outliers just by looking at the distribution , outliers refers to those extreme higher or lower values which effect the reliability of the data.
#
#      There are mainly 3 types of kurtosis
#
#      . Mesokurtic - moderate peak ( just like normal distribution)
#
#      . Leptokurtic - high peak (presence of extremeties)
#
#      . Platykurtic - flatter peak (evenly spread data)
#
# 6. Expalin why the uniform distribution is a good model for the outcome of rolling a fair die.
#
#      -> Uniform distribution is a good model for the outcome of rolling a fair die, as this type of distribution gives equal weightage to all the possible outcomes , hence making the data more reliable and fair, reflecting equal probability for each outcome, i.e 1/6
#
# 7. Use excel to compute the probability of getting atleast 8 successes in 15 trials with success probability 0.5 .
#
#       -> The probability is 0.5 .
#
# 8. How does log transformation helps in stabalizing variance and making data more normally distributed.
#
#        -> Log transformation helps in reducing the effect of extreme outliers which help stablaize the data and making it more normally distributed, it is applied where data is highly positievely skewed i.e right taildness of data is more which affects the normal distribution of the rest of the data.
