# %% [markdown]
# <a href="https://colab.research.google.com/github/srishtiarora42006-hue/Answer/blob/main/covariance_and_corelation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.  Define Covariance and explain how it differs from Correlation in terms of scale and interpretation.
#
#      -> covariance measures to change of scale in between 2 variables, whereas corelation is a statistical measure which shows the extent upto which two variables move together . covariance tells the direction but co relation tells direction and strength of relationship in between 2 variables.
#
#
#
# 2. What does a positive, negative, and zero covariance indicate about the relationship between two variables?
#
#       -> covariance values can be categorised into 3 types
#
#      positive covariance- where one variable increases and other one also increases
#
#      negative covariance- where one variable increaeses and other one decreases
#
#      zero covariance- no relationship in between both variables
#
#
# 3. Discuss the limitations of covariance as a measure of relationship between two variables. Why is correlation preferred in many cases?
#
#    ->  covariance has a limitation of just telling the direction also it depends heavily on scale of the variables, i.e if we change the scale of one of the variables then the relationship between the variables might not change but the values will, ultimately questioning reliability of covariance in between 2 variables, correlation gives us the strength as well as the direction of the relationship, and diffrent values indicate the strength and weakness of the relationship, it helps in data validation and also for forecasting future prospects.
#
#
# 4. Explain the difference between Pearson’s correlation coefficient and Spearman’s rank correlation coefficient. When would you prefer to use Spearman’s correlation?
#
#      ->  Pearson"s correlation coefficient conisers actual numeric values from the data, it assumes the data to be normally distributed and works on linear relationship between 2 variables, on the other hand spearman's rank correlation coefficient method focuses on ranking of the data and then its analysis, it does not assumes for the data to be normally distributed and most importantly it is free from the effect of outliers, which help in reliability of the data for further analyis, hence these feautres make the spearman's rank coeffiecent correlation method to be more preferable than the pearson's one.
#
#
#
# 5. If the correlation coefficient between two variables X and Y is 0.85, interpret this value in context. Can you infer causation from this value? Why or why not?
#
#    -> if the correlation coefficent between 2 variables X and Y is 0.85 it indicates a strong positive relationship, i.e if one increases other also tends to increase in the similar way , generally correlation does not cause causation that means in every sceneario it is not possible that one causes the another, here causuation is not there between the variables X and Y.
#
# 6. . Using the dataset below, calculate the covariance between X and Y.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# -> covariance = calculate mean of X nd Y =
# X = 2+4+6+8 /4 = 20/4 = 5
# Y = 3+7+5+10/4 = 25/4 = 6.25
#  NOW we calaculate X- MEAN OF X =  2-5 = -3
#
#                                   4-5 = -1
#
#                                   6-5 =  1
#
#                                   8-5=   3
#
# NOW  we calculate Y - MEAN OF Y = 3- 6.25 = -3.25
#
#                                   7-6.25 = 0.75
#
#                                   5- 6.25 = -1.25
#
#                                   10 - 6.25 = 3.75
#
# ( ∑X-Xˉ) (Y−Yˉ)  = -3* -3.25 = 9.75
#                     -1 * 0.75 = -0.75
#                     1* -1.25 = - 1.25
#                     3* 3.75 = 11.25
#                     9.75+ 11.25 - 0.75-1.25 = 19
#
#                     COVARIANCE = 19/ 4-1 = 19/ 3 = 6.33
#                     HENCE = Cov(X,Y)= 6.33
#
#
# 7. Compute the Pearson correlation coefficient between variables A and B:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#      -> data = A (X) = 10,20,30,40,50
#                B (Y) = 8,14,18,24,28
#
#      MEAN = 10+20+30+40+50 / 5 = 150/5 = 30
#           = 8+14+18+24+28 = 92/5 = 18.4
#
#      Now wecalculate X−X̄ = 10-30 = -20
#                            20 -30 = -10
#                            30-30 = 0
#                            40- 30 = 10
#                            50- 30 = 20
#
#                   (Y−Yˉ) = 8-  18.4 =  -10.4
#                            14- 18.4 =  -4.4
#                            18- 18.4 =  -0.4
#                            24- 18.4 =  5.6
#                            28- 18.4 =  9.6
#
#                 Product = -20* -10.4 =  208
#                           -10* -4.4= 44
#                            0* -0.4=  0
#                            10* 5.6 = 56
#                            20* 9.6 =  192
#
#    adding all = 208+ 44+  56+ 192 = 500
#
#    ∑(A−Aˉ)(B−Bˉ)=500
#
#    ∑(A−Aˉ)^2 = 400+100+100+400 = 1000
#    (B−Bˉ)^ 2 = 108.16 + 19.36 + 0.16 + 31.36 + 92.16 = 251.2
#
#    r= 500 / √1000*251.2 = 500/ √251200 = 500/501.2 = 0.998  answer

# %% [markdown]
# 8. 8. . The following table shows heights (in cm) and weights (in kg) of 5 students. Find the correlation coefficient between Height and Weight.

# %% [markdown]
# ![Screenshot 2026-04-27 153448.png](data:image/png;base64,...)

# %% [markdown]
#  -> HERE X = 150,160,165,170,180
#          Y = 50, 55, 58, 62, 70
#
#      Now we calculate mean of X = 150+160+165+170+180 / 5= 165
#                               Y = 50+ 55+ 58+ 62+ 70 /5 = 59
#
#      Now we calculate X−X̄ =  150-165 = -15    Y−Ȳ= 59- 50 =-9
#                              160- 165 = -5         59-55 = 4
#                              165-165 =0            59-58 = 1
#                              170- 165 = 5           59-62  = -3
#                              180- 165 = 15         59- 70 = -11
#
#
#       (X−X̄)² = 225 + 25+0+25+225=  500
#       (Y−Ȳ)² = 81+ 16+1 + 9+ 121 = 228
#       (X−X̄)(Y−Ȳ) = 135 , 20, 0 , 15 , 165
#        adding (X−X̄)(Y−Ȳ) = 135+20+0+15+165 =  335
#
#        335/√500*228 = 335/ √114000 = 335/337.64 =** 0.99 answer **
#
# 9.  Given the dataset below, determine whether there is a positive or negative correlation between X and Y. (No need for exact calculation, just reasoning.)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  -> The above dataset shows a negative correaltion in between the variables X and Y, as x keeps on increasing Y keeps on decreasing , that means both move in opposite directions, hence showing non linear realtionship , thus there exists a negative correaltion between X and Y.
#
#  10.  Two investment portfolios have the following returns (%) over 5 years. Compute the covariance and
# correlation coefficient, and interpret whether the portfolios move together.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# -> Here data = A(X) = 8,10,12,9,11
#                B(Y) = 6,9,11,8,10
#
# Now we calcualte mean of X = 8+10+12+9+11 / 5 = 50/5 = 10
#                          Y = 6+9+11+8+10 / 5 = 44 /5 = 8.8
#
# Now we calculate covariance i.e ∑(x−xˉ)(y−yˉ​)​ / n
# so we calculate X−X̄ = 8-10 = -2          Y−Ȳ = 6-8.8 = -2.8
#                       10-10 = 0             9- 8.8 = 1.8
#                       12-10 = 2             11-8.8 = 2.2
#                       9-10 = -1             8- 8.8 = -0.8
#                       11-10 = 1             10-8.8 = 1.2
#
# Now we take product = -2 * -2.8 = 5.6
#                       0* 1.8 = 0
#                       2* 2.2 = 4.4
#                       -1* 0.8 = 0.8
#                       1* 1.2 = 1.2
#
# Adding all of this = 5.6 + 0+ 4.4 + 0.8 + 1.2 = 12
# covariance = 12 / 5 = 2.4
#
# Now we calculate correlation , as we already have the numerator = 12
#
# ∑(X−Xˉ)2= 4+0+4+1+1=10
#
# and
#
#  ∑(Y−Yˉ)2=7.84+0.04+4.84+0.64+1.44=14.8
#
#  12 / √10*14.8 = 12/ √148 = 12/ 12.17 = 0.99
#  hence this represents strong positive correaltion
#
#
#  **HENCE , it can be interpreted that both the portfolios move together showing a strong relationship. **
