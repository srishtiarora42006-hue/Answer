# %% [markdown]
# <a href="https://colab.research.google.com/github/srishtiarora42006-hue/Answer/blob/main/pivot_table_in_excel_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. what is the role of pivot table in excel?
#
#    -> Raw data is messy and dificult to understand, pivot tables help to summarise large datasets which help to understand data effieciently and take quick decisions. it also helps in creating attractive datasets and charts using pivotcharts to analyse the patterns and data in them easily.
#
# 2.  Create a pivot table to show total sales by region.
#
#     ->

# %% [markdown]
# ![Screenshot (10).png](data:image/png;base64,...)

# %% [markdown]
# 3. Apply conditional formatting to highlight sales gretaer than 400.
#
# 4. explain the diffrence between sorting and filtering with an example from this dataset.
#
#      -> sorting refers to arranging the data in a particular order ascending or desceding it only confers to the arrangement of data, whereas filtering refers to showing only selected data and hiding the rest.
#
#      -> In this dataset values have been arranged newset to oldest which means data has been sorted, and filter has also been applied which alows the user to select some specifications and view data as per that.
#     for eg. sales only for the month of january and the quantity sold.

# %% [markdown]
# ![Screenshot (8).png](data:image/png;base64,...)

# %% [markdown]
# 5. Create a pivotchart using Monthly sales trend.![Screenshot (9).png](data:image/png;base64,...)

# %% [markdown]
# 6. Use a slicer to filter Data by product and observe changes in sales.
#
#   -> ![Screenshot (11).png](data:image/png;base64,...)

# %% [markdown]
# 7. Why are Dasboards important for decision making in business analysis.
#    -> Dasboards summarise the specs of the data on one screen, so instead of scanning through whole data the analyst can just view that one screen to take any important decision, which saves a lot of time and reduces the chances of any wrong decision being made due to unavailalabilty of important data at a single place.
#
# 8. Create a Dashboard that includes:
#    sales by region (pivottable+ chart)
#    Product filter(slicer)
#    Monthly trend (Line chart)
#
#  ->

# %% [markdown]
# ![Screenshot (13).png](data:image/png;base64,...)

# %% [markdown]
# 9. Group dates in Pivot Table into Months and calculate average sales per month.
#    -> ![Screenshot (14).png](data:image/png;base64,...)

# %% [markdown]
# 10. Combine Apples and Oranges into one group called Fruits and Compare its sales with other products.
#     -> ![Screenshot (15).png](data:image/png;base64,...)
