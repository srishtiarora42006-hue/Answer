# %% [markdown]
# <a href="https://colab.research.google.com/github/srishtiarora42006-hue/Answer/blob/main/Descriptive_statistics_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. A bakery tracks daily sales of muffins (in dozens) over a week : [10,12,11,15,14,13,12]. what is the most representative value of their weekly sales, and why?
#
#    -> The most representative value refers to mean as it shows an average value from the dataset which represents whole of the data. means can be calculated as sum of values divided by number of values so here mean refers to sum of data which comes out to be 87 divided by number of values i.e 7 so mean = 12.42
#
# 2. A teacher records the marks of students in a short quiz: [12,15,14,16,18,20,19] what is the mean score and what does it tells us about the class performance?
#
#      ->  The mean score refers to the average score of  the class which represents the performance of the whole class, it can be calculated by dividing the sum of all the marks by no of marks in the data so mean = 12+15+14+16+18+20+19/7 so mean is 16.28 this tells us that on an average the marks scored by the students of the class can be collectively represented as an average score of 16.28.
#
# 3.  A store records the shoe sizes sold in one day : [7,8,9,8,8,10,7,9] what is the mode and why is this information useful for the store manager.
#
#      -> The mode of the above given data is 8 as mode refers to the most occuring value and here 8 occurs the most number of times that is 3 times that also means the shoe of size 8 was sold maximum and this information is useful for the store manager as from this data he can evidently summarise that he needs to maintain the stock of shoe size 8 more than the rest of the sizes as it sells the most among customers.
#
# 4.  A car dealer notes the prices of used cars :[ $8000, $9500,  $10200, $11000, $50000]. why is the median a better measure than the mean in this case ? calculate the meadian.
#
#      -> Median refers to the mediator value from the data after sorting it in ascending or descending order , it is a better indicator in this case as it is free from the effect of outliers that deflect the value of mean , here the data is already sorted so the median can be directly calculated which is $10,200 which is middle value.
#
# 5. A student times how long it takes to finish a puzzle each day :[25,30,27,35,40]. what does the range tell us about the variation in the student's puzzle solving time?
#
#      -> Well range refers to  difference of highest value and the lowest value , here range of the data is 40-25= 15 which means that he took longest time to finish a puzzle of 40 mins a day to lowest time being 25 mins in a day that is a variation of 15 mins.
#
# 6.  A farmer records the weekly weight if harvested apples (kg) : [100,105,98,110,120] Find the range. HOw can this help the farmer in planning his packagaing?
#
#      -> The range of the data is 120-98 = 22 this shows us along the week maximum variation of weight which occured was of 22 kgs so the farmer needs to plan his packaging material or quantity in such a way that it can vary upto 22 kgs heavier and lower both so as to cause no damage to the apples in the packaging due their inappropriate weight holding capacity .
#
# 7.  Variance for decision making
#   Two delivery companiea track delivery delays ( in minutes) .
#   . company A : Variance = 6
#   . comapny B : Variance = 15
#    Which company is more consistent and why?
#
#      -> Among both of these companies Company A has a lower variance of 6 units as compared to variance of Company B i.e 15 units higher variance means more fluctuations and less stability hence while making a decision less variance alternative should be preferred which is apparently less volatile and more stable , hence Company B is more stable and consistent.
#
#   8. A finance student compared the daily price fluctuations of two crypto currencies.
#   . Coin A : standard deviation =$30
#   . Coin B : standard deviation = $ 120
#    which coin is riskier to invest in and why?
#
#        -> Standard deviation shows how far are values from mean from both positive and negative side , it means it tells  us how far the values lie in a standard sequence , here in this question the standard deviation of coin B is more which means it lies far way than the average price fluctuations so it is riskier to invest in on the other hand standard deviation of coin A is less which shows it's price fluctuations are near average only which means it is safer to invest in.
#
#
#
#
#   9. A family records their monthly electricity usuage (in Kwh) : [400,420,390,450,410]. Find the mean and standard deviation . what do these values together tell you about the family's energy use pattern?
#
#       -> The mean  of the above data is 414 and standard deviation can be calculated by the square root of variance and deviations first
#       deviations = (400-414)², (420-414)², (390-414)², (450-414)², (410-414)² = (-14)²+ (6)² + (-24)² + (36)² + (4)² = 2120 / 5 = 424 so standard deviation = √424 = 20.59
#       hence this gives us an Idea that the monthly usuage of electricity in kwh of this family varies in a range of 20.59 units , higher or lower.
#
#
# 10.  A basketball player's points in 8 games are recorded :[15,18,20,22,25,17,19,21] Find the mean , median, mode, range and standard deviations , what insights can these vvalues pprovide about the player's performance .
#
#      -> mean = 19.6
#       median = 19
#       mode= no mode or 0
#       range = 25-18 = 7
#       variance = 8.48
#       standard deviation = 2.91
#
#       these values tell us about the average score of player, average deviation that is variance and standard deviations.
