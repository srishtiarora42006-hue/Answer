# %% [markdown]
# <a href="https://colab.research.google.com/github/srishtiarora42006-hue/Answer/blob/main/SQL_Basics_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Q1. Create a New Database and  Table for Employees
#
# Task: Create a new database named and Create a table named with the following
# columns:
#
# 2.  Insert Data into Employees Table
#
# Task: Insert the following sample records into the  EMPLOYEES table.
#
#
# ![Screenshot 2026-05-05 180240.png](data:image/png;base64,...)

# %% [markdown]
# 3. Display All Employee Records Sorted by Salary (Lowest to Highest)
#
# Hint: Use the ORDER BY clause on the salary column.
#
# ![Screenshot 2026-05-05 172522.png](data:image/png;base64,...)

# %% [markdown]
# 4. Show Employees Sorted by Department (A–Z) and Salary (High → Low)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5. List All Employees in the IT Department, Ordered by Hire Date (Newest First)
#
# ![Screenshot 2026-05-05 172606.png](data:image/png;base64,...)

# %% [markdown]
# 6. Create and Populate a Sales Table
#
# Task: Create a table to track sales data:
#
# ![Screenshot 2026-05-05 174322.png](data:image/png;base64,...)

# %% [markdown]
# 7. Display All Sales Records Sorted by Amount (Highest → Lowest)
#
#
# ![Screenshot 2026-05-05 174419.png](data:image/png;base64,...)

# %% [markdown]
# 8. Show All Sales Made by Customer “Aditi”.
#
# ![Screenshot 2026-05-05 174842.png](data:image/png;base64,...)

# %% [markdown]
# 9. What is the Difference Between a Primary Key and a Foreign Key?
#
#   -> primary key combines the function of not null and unique, it contains a value which cannot be zero and has to be diffrent as well. there can be  more than one primary keys in a table. Foreign key links a specific data column of one table with that of another to establish a common base for further linking of the two tables.
#
# 10.  What Are Constraints in SQL and Why Are They Used?
#
#      -> constarints are rules which are applied to the columns of a table, they are used to ensure data integrity, its accuracy, and to maintain reliability of the data. the constraints often used are : NOT NULL, UNIQUE, PRIMARY KEY, FOREIGN KEY ETC.
