# %% [markdown]
# <a href="https://colab.research.google.com/github/srishtiarora42006-hue/Answer/blob/main/Tableau_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Q1.**  Explain what Tableau is and why it is preferred over traditional spreadsheet tools for data analysis.
#
# Also mention any two industries where Tableau is commonly used and explain one use case.
#
# -> Tableau is preferred over traditional spreadsheet tools for data analysis as it supports large datasets with a lot of visualisations which helps to present the key insights nicely,also tableau is a user friendly platform with various customisations and options helping users to make an interactive report.
# Tableau is commonly used in many industries such as retail,supply chain management, finance, healthcare , marketing etc.
#
# Use case - to analyse trends, maximum and minimum sales, region wise sales or profit, comparing various products and quantity sold etc.
#
# **Q2.** After connecting to the Sample – Superstore dataset:
#
# a) List the main types of fields available (examples: time-based, geographical, numerical).
#
# -> ship date - date
#    country/region - geographical
#    sales - numerical
#    profit - numerical
#    quantity - numerical
#
# b) Identify any four Dimensions and any four Measures from the dataset.
# Hint: Look at the Data Pane on the left side of Tableau and observe blue (Dimensions) and green (Measures)
# fields.
#
# -> DIMENSIONS - Ship mode , segment, order ID, Ship date
#    MEASURES - Profit, quantity, sales, Discount
#
# **Q3.** Create a Bar Chart showing Total Sales by Category.
#
# Explain:
#
# Which field goes to Rows -> sales
#
# Which field goes to Columns -> product and sub category
#
# Which aggregation is applied to Sales -> sum
#
# Hint: Drag Category and Sales into the view and observe Tableau’s default behavior.
#
# -> ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Q4.** What insight can be gained by comparing Sales and Profit together?
#
# -> If we compare sales and profit together we can get to know the relationship between sales and profit and how propotionate increase or decrease in sales effects profits.
#
# Then explain how you would create a chart to analyze Profit by Sub-Category.
#
# Hint: Use Sub-Category as a Dimension and Profit as a Measure.
#
# -> ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Q5.** Create a Line Chart to show Sales Trend over Order Date.
#
# Which date level would you choose (Year / Quarter / Month)?
#
# Why are line charts suitable for time-based analysis?
#
# Hint: Drag Order Date and change its date hierarchy from Year to Month if needed.
#
# -> Line charts are used for time based analysis as they best depict how data chnages over the time , aspects such as sales, profit, discount etc change over continuos periods, this also helps to ascertain peak and dips details , through line charts one can also analyse multiple trends over the time and highlight the important lines.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Q6.** Apply a Basic Filter to display data only for:
#
# Region = “West”
#
# Category = “Technology”
#
# Explain the steps and mention which shelf is used.
#
# Hint: Drag the required fields to the Filters shelf and select appropriate values.
#
# -> ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Q7.** Explain the business importance of geographical analysis.
#
# Then describe how you would create a Map showing Sales by State using Sample – Superstore.
#
# Hint:  Use State and Sales. Tableau automatically detects geographic fields.
#
# -> Geographical analysis helps a business to understand their product market as per the location, it teels how much of sales,profit,orders etc come from a particular area which further assits in formulating business decisions,goals ,schemes and deals for that area .
#
# To create a map showing sales by state firstly drag the required dimension that is state/province into the detail box in the marks card, then drag the sales measures into colour box again under the marks card, now on the right side click on the filled map visualisation and map will be ploted showing sales as per state.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Q8.** What is the difference between a Worksheet and a Dashboard in Tableau?
#
# Why is a dashboard more useful for decision-makers?
#
# -> In tableau a worksheet is a particular sheet where one works on and adds one specific visualisation which represents the data in the form of bar,pie,line chart etc. Whereas tableau offers a special feautre to add new dashboard where one can add all the reports made by using worksheets at one singular place, this offers the users of these reports and dashboards to get an overview or the key insights from the data, dashboards in tableau are more interactive and one can customise and adjust a number of reports made in there which offers a comprehensive view and provides a clear view of the data at a glance which leads to quick and effective decision making .
#
# **Q9.** What is Tableau Prep, and why is it important in real-world data projects?
#
# Then explain how you would:
#
# Remove null values
#
# Remove duplicate records
#
# Change incorrect data types (Answer in steps, no tool access required.)
#
# -> Tableau prep is used to visually clean,shape and transform the data before the analysis, it offers a real time preview for the users so that they can view the transformation before permanently applying it, it simplifies complex tasks thus making it user friendly.
#
# following are the steps to remove null values in tableau prep:-
#
# * open the dataset in tableau
# * identify the null values
# * and filter the data by clicking and adding filters on the right side of the flow pane.
#
# to remove duplicate records -
# * open the dataset in tableau
# * use the "remove duplicates" function in tableau prep
#
# to change incorrect data type:
# * load the dataset into tableau prep
# *the data grid shows the data type in the column
# * click on the data type you want to change and select the correct data type.
#
# **Q10.**  A retail manager wants answers to the following:
#
# Which category generates the highest profit?
#
# Which region performs poorly?
#
# How does sales change over time?
#
# a) Mention which charts you would use
#
# -> to ascertain the highest profit we will use **Bar chart** , to know which region performs poorly we can use a **pie chart** and to understand sales over time we will use **line chart**.
#
# b) Identify one key insight that management could derive.
#
# -> That furniture yields the least profit out of the three categories.
#
# c) Explain how this helps in business decision-making
#
# -> This helps in decision making as the management can decide weather to sell furniture or not, or increase the profit ratio from the furnitures, to cut down any unnessary or high cost being paid for furniture.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
