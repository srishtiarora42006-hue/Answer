# %% [markdown]
# <a href="https://colab.research.google.com/github/srishtiarora42006-hue/Answer/blob/main/Data_loading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Q1**. Data Understanding
#
# Identify all data quality issues present in the dataset that can cause problems during data loading.
#
# -> All the data quality issues present in this dataset which can cause problems during data loading are listed below
#
# ▶ 1. Duplication of data - order_ID 101 being repeated twice.
#
# 2. Null value in sales_amount column at order_ID o102 .
#
# 3. Amount written in wrong format - three thousand.
#
# 4. Date written in wrong format at order_ID O103.
#
# **Q2**. Primary Key Validation
#
# Assume order_ID is the Primary Key.
#
# a) Is the dataset violating the Primary Key rule?
#
# -> yes, the primary key rule is being violated in this dataset as repition is there in the column.
#
# b) Which record(s) cause this violation?
#
# -> Order-ID O101 is causing this violation.
#
# **Q3**. Missing Value Analysis
#
# Which column(s) contain missing values?
#
# a) List the affected records.
#
# -> the sales_amount at order_id o102 contains a null value.
#
# b) Explain why loading these records without handling missing values is risky.
#
# -> loading these records directly to BI tools or for formulation of reports and dashboards can certainly lead to wrong conclusions, as due the missing value, the overall calculation of any aggregate variable can be affected, for eg if company wants avg sales_amount or its summation , the results would be misleading and wrong , thus making the data unreliable.
#
# **Q4**. Data Type Validation
#
# Identify records where Sales_Amount violates expected data type rules.
#
# a) Which record(s) will fail numeric validation?
#
# -> record with order_id o104 will fail numeric validation.
#
# b) What would happen if this dataset is loaded into a SQL table with sales_amount as DECIMAL?
#
# -> There will probably be an error and will be unable to load the table into SQL , as the value is string and not a decimal.
#
# **Q5**. Date Format Consistency
#
# The order_date column has multiple formats.
#
# a) List all date formats present in the dataset?
#
# ->  The formats present in the order_date column are :
#
# * DD-MM-YYYY
# * YYYY-MM-DD
#
# b) Why is this a problem during data loading?
#
# -> This is a big problem during data loading, as the formats of the dates are diffrent so it would lead to hardships in its final analysis, while transforming the data , data standardization is an important task, which ensures uniformity within columns.
#
# **Q6**. Load Readiness Decision
#
# Based on the dataset condition:
#
# a) Should this dataset be loaded directly into the database? (Yes/No)?
#
# ->  NO
#
# b) Justify your answer with at least three reasons
#
# ->
# * Because of improper and uneven formats of dates present in order_date column.
#
# * because the sales_amount column has a null value and a value written in wrong format which needs to be corrected.
# * There is duplication of order_Id o101, because of which there is an entire record being repeated.
#
# hence, this dataset cannot be directly loaded into the database because of the above mentioned reasons.
#
# **Q7**. Pre-Load Validation Checklist
#
# List the exact pre-load validation checks you would perform on this dataset before loading.
#
# -> the pre load validation checks which will be performed are ▶
#
# * checking if there are any duplicate records.
# * if data is in the right formats as per the column.
# * if there any null values present .
# * replacement of the null values (if present) through the correct method.
# * ordering the data as per a particular format.
#
#
# **Q8**. Cleaning Strategy
# Describe the step-by-step cleaning actions required to make this dataset load-ready.
#
# -> The cleaning steps required to make this dataset load-ready are:
#
# 1. remove all the duplicates from the data.
# 2. replacing the null value , this can be done by various ways
#
#        * imputation through mean, median or mode.
#        * replacing the data by doing predictive analysis.
#        * deleting the null value.
#        * flagging the null values.
#
# 3. performing the task of data standardization to correct all the improper formats on order_date column .
# 4. correcting the sales_amount by  column by proper value input.
#
# **Q9**. Loading Strategy Selection
#
# Assume this dataset represents daily sales data.
#
# a) Should a Full Load or Incremental Load be used?
#
# -> Incremental load should be used .
#
# b) Justify your choice.
#
# -> Incremental load only loads that data which is fresh and new, it loads the daily new data instead loading the whole dataset again which also takes a lot of time and may lead to errors in between loading , incremental load on the other hand is faster and loads faster, which saves a lot of time.
#
#
# **Q10**. BI Impact Scenario
#
# Assume this dataset was loaded without cleaning and connected to a BI dashboard.
#
# a) What incorrect results might appear in Total Sales KPI?
#
# -> In the total sales KPI  the aggreagate value will be incorrect i.e 17,300.
#
# b) Which records specifically would cause misleading insights?
#
# -> Order_ID o101, o102 and o104, specifically will lead to these wrong business insights as o101 is being repeated twice which will lead to double summation of the same record ,o102 represents null sales_amount value and o104 is written in the wrong format i.e "three thousand" which will not be added up while calculating total sales , thus providing a wrong result which will not be reliable.
#
# c) Why would BI tools not detect these issues automatically?
#
# -> BI tools are business intelligence tools which are used to form reports and further conduct their analysis, these tools are not data cleaning or transforming tools, however they may contain some functions to transform the data to make it accurate for the further steps.
