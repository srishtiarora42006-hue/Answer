# %% [markdown]
# <a href="https://colab.research.google.com/github/srishtiarora42006-hue/Answer/blob/main/Excel_with_copilot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot_20260415-164821.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot_20260415-164834.jpg](data:image/jpeg;base64,...)
