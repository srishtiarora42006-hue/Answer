# %% [markdown]
# <a href="https://colab.research.google.com/github/srishtiarora42006-hue/Answer/blob/main/probability_distribution_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1. A die is rolled. What is the probability of getting
 (a) An even number
 (b) A number greater than 4.

     -> (a)- posibilities of getting an even number = 3
              total outcomes- 6
              probability- 3/6 = 1/2 = 0.5
        (b)- possiblities of getting a number greater than 4= 2
             total outcomes- 6
             probability = 2/6= 1/3 = 0.33

2. In a class of 50 students :
  . 20 like mathematics (M)
  . 15 like science (S)
  . 5 like both subjects
  What is the probability that a student chosen at random likes Mathematics or Science?

     -> Here addition rule will be applied
       That p(M and S) = p(M) + p(S) - p(M and S)
                       =20/50 + 15/50 - 5/50
                       =2/5 + 3/10 - 1/10
                       = 7/10 - 1/10
                       = 6/10
                       = 0.6

3. A bag has 3 red and 2 blue balls . If one ball is drawn randomly and it is red , what is the probability that the next ball is also red (without replacement).
   -> The probability of getting  red ball again without replacement means now we have only 2 red balls left so the probability will be 1/2= 0.5


4. The population of a school is divided into 60% boys and 40% girls. If u want equal representation of both the genders in the sample, which method you should use: simple random sampling or stratified sampling? why?

  -> In this case stratified sampling should be used as there is already an unequal distribution of both the groups and simple random sampling can lead to weightage of just one group over the other, whereas stratified sampling will lead to division of data into diffrent stratas as per their characterstics, which ultimately leads presesntation of the whole population.

5.  The average height of 1000 students = 160 cm. A sample shows an average height = 158 cm. Find the sampling error.

   -> Sampling error refers to the difference between the sample mean and the population mean which occurs due to randomness of the sample, here sampling error= 2cm.

6. The population mean salary is ₹50000 with standard deviation of 5000, if we take a sample of 100 employees, what is the standard error of mean (SEM) ?
      -> Standard error of mean = 5000/100= 5000/100= 0.5

7. In a group of 100 students:
  -40 like cricket (C)
  -30 like football (F)
  -10 like cricket and football
  Find the probability that a student likes at least one sport.

     -> total possibilities = 80 in which 10 outcomes are overlapping
        so addition rule can be applied
        p(C or F) = p(C) + p(F) - p(C and F)
                     = 40/100 + 30/100 - 10/100
                     = 70/100 - 10/100
                     = 60/100
                     = 0.6

8. From a deck of 52 cards, two cards are drawn without replacement, what is the probability that both are aces.

   -> multiplication rule will be applied here
    p(A and B) = P(A)*P(B)
               = 4/52 * 3/51
               = 12/2652
               = 1/1326
               = 0.0009


  9. A factory produces bulbs with 2% defective rate. If 5 bulbs are  selected at random, what is the probability that all are non defective ?

    -> The probability of the bulb being defective = 5*2% = 0.1
      so P(E') = 1-0.1 = 0.9
      hence the probability of the bulb being non defective is 0.9.

  10. Diffrentiate between discrete and continuos random variables with examples.

    -> discrete random variables takes only integers as the values for eg. 1,2,3,4
      continuos random variables takes any value from the range that can be any decimal or fractions also for eg. temperatures, heights etc
