# %% [markdown]
# <a href="https://colab.research.google.com/github/srishtiarora42006-hue/Answer/blob/main/Tableau_visualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Task 1: Category Performance Analysis
#
# Business Need:
# Management wants to know which product categories generate the highest revenue.
#
# Task:
# Create a visualization to compare total Sales by Category and identify the top-performing category.
#
# -> The top performing category is Technology.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Task 2: Sales Trend Analysis
#
# Business Need:
# The leadership team wants to understand how sales fluctuate over time to plan promotions and inventory.
#
# Task:
# Analyze Sales trends over time (monthly) to identify peak and slow periods.
#
# -> ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Task 3: Regional Contribution Analysis
#
# Business Need:
# The regional managers want clarity on how much each region contributes to overall sales.
#
# Task:
# Visualize Region-wise Sales contribution and identify the highest contributing region.
#
# -> West is the highest contributing region.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Task 4: Profitability Investigation
#
# Business Need:
# The finance team suspects that some high-sales orders may be reducing overall profit.
#
# Task:
# Analyze the relationship between Sales and Profit to identify loss-making or low-profit orders.
#
# -> ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5. Task 5: Business Growth Evaluation
#
# Business Need:
# Senior management wants to assess whether the business is growing consistently.
#
# Task:
# Visualize cumulative Sales growth over time to evaluate overall performance.
#
# -> ![image.png](data:image/png;base64,...)

# %% [markdown]
# Task 6: Category vs Region Performance
#
# Business Need:
# Operations wants to know which regions perform well for each product category.
#
# Task:
# Compare Category-wise Sales across Regions to identify strong and weak market areas.
#
# -> ![image.png](data:image/png;base64,...)

# %% [markdown]
# 7. Task 7: Product Prioritization
#
# Business Need:
# The product team wants to focus on products that create maximum business impact.
#
# Task:
# Perform a multi-dimensional analysis using Sales, Profit, and Quantity to identify priority products.
#
# -> ![image.png](data:image/png;base64,...)

# %% [markdown]
# 8. Task 8: Executive Dashboard Creation
#
# Business Need:
# The CEO wants a single view dashboard that summarizes key insights.
#
# Task:
# Create an interactive dashboard combining at least three visualizations and apply filters such as Region or
# Category.
#
# -> ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Q9.** Chart Selection Justification
#
# Explain why different charts were used for different business questions in this analysis.
#
# -> Diffrent visuals reflect diffrent type of insights, these various types of insights helps to analyse trends, comparisons, growth rate, major and minor areas etc , all these charts show diffrent kinds of relationship between measures and dimensions which further helps to bring out various results which further help in decision making and formulation of future plans and agendas. for eg. bar charts help to display comparison between 2 variables alongside, pie charts show diffrent segregations among categories or regions, heat map shows colur grading , filled map can be used to show data in diffrent states, provinces , countries etc, in this way diffrent charts help to analyse diffrent results gained from them.
#
# **Q10.** Business Insight Summary
#
# Summarize two key insights from your dashboard and explain how they can help management make better decisions.
#
# -> The two key insights which can be derived from the above dashboard are :-
#
#
# 1. Technology is the highest selling category in all the regions.
#
# * The management should enhance schemes, discounts and selling strategies for the rest of the two categories i.e Furniture and office supplies, also improve customer services for the technology aspect to increase customer satisfaction and customer retention.
#
# 2.  Sales peak at the time of january.
#
# * Hence, the management should continue the strategy which is used in the month of january and it should be implemented often and other schemes and should be introduced to maintain the hike of sales whole of the year.
